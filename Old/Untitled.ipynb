# %%
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# Ваши данные
x = [1, 366, 731, 1096, 1461, 1826, 2191, 2556]  # Дни
y = [1,18431, 271175, 368253, 521983, 726415, 1002382, 1373495]

# Создать функцию интерполяции
interp_func = interp1d(x, y, kind='cubic')


for i in range(500):


    # Интерполировать значение для дня
    year_interpolated = interp_func(i+1)
    year_interpolated_2 = interp_func(i+2)

    count = year_interpolated_2 - year_interpolated


    # print(count)

xnew = np.arange(1,2500,1)
ynew = interp_func(xnew)
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()
